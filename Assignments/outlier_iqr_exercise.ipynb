# %% [markdown]
# <h2 align='center' style='color:blue'>Exercise: Outlier Detection and Removal Using IQR</h2>

# %% [markdown]
# You are given height_weight.csv file which contains heights and weights of 1000 people. Dataset is taken from here,
# https://www.kaggle.com/mustafaali96/weight-height
#
# You need to do this,
#
# (1) Load this csv in pandas dataframe and first plot histograms for height and weight parameters
#
# (2) Using IQR detect weight outliers and print them
#
# (3) Using IQR, detect height outliers and print them

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
file_path = 'height_weight.csv'
df = pd.read_csv(file_path)

# Plot histograms for height and weight
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(df['height'], bins=30, edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(df['weight'], bins=30, edgecolor='black')
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Out:
#   gender     height      weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# **Histgram for weights**

# %% [markdown]
# **Histgram for heights**

# %% [markdown]
# **Detect outliers based on weight, Q1, Q3, IQR**

# %%
# Calculate IQR for weight
Q1_weight = df['weight'].quantile(0.25)
Q3_weight = df['weight'].quantile(0.75)
IQR_weight = Q3_weight - Q1_weight

# Determine lower and upper bounds for weight outliers
lower_bound_weight = Q1_weight - 1.5 * IQR_weight
upper_bound_weight = Q3_weight + 1.5 * IQR_weight

# Identify weight outliers
weight_outliers = df[(df['weight'] < lower_bound_weight) | (df['weight'] > upper_bound_weight)]
weight_outliers
# Out:
#      gender     height      weight
# 2014   Male  78.998742  269.989699

# %% [markdown]
# ### IQR

# %%
# Out:
# 51.35147356318197

# %% [markdown]
# ### Upperlimit, lowerlimit

# %%
# Out:
# (58.79084096072856, 264.19673521345646)

# %% [markdown]
# ### Find the outlier records

# %%
# Out:
#      gender     height      weight
# 2014   Male  78.998742  269.989699

# %% [markdown]
# **Detect outliers based on height Q1, Q3**

# %%
# Calculate IQR for height
Q1_height = df['height'].quantile(0.25)
Q3_height = df['height'].quantile(0.75)
IQR_height = Q3_height - Q1_height

# Determine lower and upper bounds for height outliers
lower_bound_height = Q1_height - 1.5 * IQR_height
upper_bound_height = Q3_height + 1.5 * IQR_height

# Identify height outliers
height_outliers = df[(df['height'] < lower_bound_height) | (df['height'] > upper_bound_height)]
height_outliers
# Out:
#       gender     height      weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 7294  Female  54.873728   78.606670
# 9285  Female  54.263133   64.700127

# %% [markdown]
# ### IQR

# %%
# Out:
# 5.668641245615746

# %% [markdown]
# ### Upperlimit, lowerlimit

# %%
lower_bound_height
upper_bound_height
# Out:
# 77.67722359525831

# %% [markdown]
# ### whole code together

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
file_path = 'height_weight.csv'
df = pd.read_csv(file_path)

# Plot histograms for height and weight
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(df['height'], bins=30, edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(df['weight'], bins=30, edgecolor='black')
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Calculate IQR for weight
Q1_weight = df['weight'].quantile(0.25)
Q3_weight = df['weight'].quantile(0.75)
IQR_weight = Q3_weight - Q1_weight

# Determine lower and upper bounds for weight outliers
lower_bound_weight = Q1_weight - 1.5 * IQR_weight
upper_bound_weight = Q3_weight + 1.5 * IQR_weight

# Identify weight outliers
weight_outliers = df[(df['weight'] < lower_bound_weight) | (df['weight'] > upper_bound_weight)]
print("Weight Outliers:")
print(weight_outliers)

# Calculate IQR for height
Q1_height = df['height'].quantile(0.25)
Q3_height = df['height'].quantile(0.75)
IQR_height = Q3_height - Q1_height

# Determine lower and upper bounds for height outliers
lower_bound_height = Q1_height - 1.5 * IQR_height
upper_bound_height = Q3_height + 1.5 * IQR_height

# Identify height outliers
height_outliers = df[(df['height'] < lower_bound_height) | (df['height'] > upper_bound_height)]
print("Height Outliers:")
print(height_outliers)
# Out:
# Weight Outliers:
#      gender     height      weight
# 2014   Male  78.998742  269.989699
# Height Outliers:
#       gender     height      weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 7294  Female  54.873728   78.606670
# 9285  Female  54.263133   64.700127
